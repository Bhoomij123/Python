# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhoomij123/Python/blob/main/DA_AG_006_Statistics_Advanced_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Assignment Code: DA-AG-006
# ## Statistics Advanced - 1 | Assignment

# %% [markdown]
# ### Question 1: What is a random variable in probability theory?

# %% [markdown]
# A random variable is a numerical quantity that represents the outcomes of a random experiment. It assigns numerical values to each outcome in a sample space. Random variables can be **discrete** (countable outcomes) or **continuous** (infinite possible values).

# %% [markdown]
# ### Question 2: What are the types of random variables?

# %% [markdown]
# 1. **Discrete Random Variable:** Takes on specific, countable values (e.g., number of heads in 5 coin tosses).
# 2. **Continuous Random Variable:** Takes any value within a range or interval (e.g., height, weight, temperature).

# %% [markdown]
# ### Question 3: Explain the difference between discrete and continuous distributions.

# %% [markdown]
# | Basis | Discrete Distribution | Continuous Distribution |
# |--------|------------------|-------------------|
# | Values | Countable | Infinite/Uncountable |
# | Example | Number of students | Height of students |
# | Probability | Sum of probabilities = 1 | Probability is defined over intervals |

# %% [markdown]
# ### Question 4: What is a binomial distribution, and how is it used in probability?

# %% [markdown]
# A **binomial distribution** represents the number of successes in a fixed number of independent Bernoulli trials with the same probability of success (p). It is used in situations like coin tosses, defect detection, or yes/no survey results.
#
# Formula:
# P(X = k) = C(n, k) * p^k * (1 - p)^(n - k)

# %% [markdown]
# ### Question 5: What is the standard normal distribution, and why is it important?

# %% [markdown]
# The **standard normal distribution** is a normal distribution with a mean (μ) of 0 and a standard deviation (σ) of 1. It allows comparison of different normal distributions using **Z-scores**, which measure how many standard deviations an observation is from the mean.

# %% [markdown]
# ### Question 6: What is the Central Limit Theorem (CLT), and why is it critical in statistics?

# %% [markdown]
# The **Central Limit Theorem (CLT)** states that the sampling distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the population distribution.
#
# **Importance:** It allows us to make statistical inferences and construct confidence intervals even when the population distribution is unknown.

# %% [markdown]
# ### Question 7: What is the significance of confidence intervals in statistical analysis?

# %% [markdown]
# A **confidence interval (CI)** provides a range of values within which the true population parameter is expected to lie with a certain level of confidence (usually 95% or 99%). It helps quantify uncertainty in parameter estimates.

# %% [markdown]
# ### Question 8: What is the concept of expected value in a probability distribution?

# %% [markdown]
# The **expected value (E[X])** is the long-run average or mean of a random variable. It represents the average outcome if an experiment is repeated many times.
#
# Formula: E[X] = Σ [x * P(x)] for discrete variables, or ∫ x f(x) dx for continuous variables.

# %% [markdown]
# ### Question 9: Write a Python program to generate 1000 random numbers from a normal distribution with mean = 50 and standard deviation = 5. Compute its mean and standard deviation using NumPy, and draw a histogram to visualize the distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(50, 5, 1000)

mean = np.mean(data)
std = np.std(data)

print(f"Mean: {mean:.2f}")
print(f"Standard Deviation: {std:.2f}")

plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title('Normal Distribution (mean=50, std=5)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
# Out:
# Mean: 50.13
# Standard Deviation: 5.19

# %% [markdown]
# ### Question 10: You are working as a data analyst for a retail company. The company has collected daily sales data for 2 years and wants you to identify the overall sales trend.
#
# **Given Data:**

# %%
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]

# %% [markdown]
# **Applying Central Limit Theorem:**
# The CLT helps estimate the average sales and its confidence interval assuming the sample mean follows a normal distribution for sufficiently large samples.
#
# We'll calculate the 95% confidence interval for mean sales.

# %%
import numpy as np
import scipy.stats as stats

sales = np.array(daily_sales)
mean_sales = np.mean(sales)
std_sales = np.std(sales, ddof=1)
n = len(sales)

confidence = 0.95
z_value = stats.norm.ppf(1 - (1 - confidence)/2)
margin_error = z_value * (std_sales / np.sqrt(n))

lower = mean_sales - margin_error
upper = mean_sales + margin_error

print(f"Mean Sales: {mean_sales:.2f}")
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# Mean Sales: 248.25
# 95% Confidence Interval: (240.68, 255.82)

# %% [markdown]
# **Interpretation:** The true average daily sales of the company are likely to fall within the computed 95% confidence interval, based on the Central Limit Theorem.
