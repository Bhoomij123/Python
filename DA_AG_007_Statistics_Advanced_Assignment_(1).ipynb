# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhoomij123/Python/blob/main/DA_AG_007_Statistics_Advanced_Assignment_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Assignment Code: DA-AG-007
# ## Statistics Advanced - 2 | Assignment

# %% [markdown]
# ### Question 1: What is hypothesis testing in statistics?

# %% [markdown]
# Hypothesis testing is a statistical method used to make inferences or draw conclusions about a population based on a sample. It helps determine whether the observed data provides enough evidence to reject a stated assumption (hypothesis) about the population parameter.

# %% [markdown]
# ### Question 2: What is the null hypothesis, and how does it differ from the alternative hypothesis?

# %% [markdown]
# **Null Hypothesis (H₀):** The assumption that there is no effect or difference.
#
# **Alternative Hypothesis (H₁):** Represents what the researcher aims to prove — that there *is* an effect or difference.
#
# Example:
# - H₀: μ = 170
# - H₁: μ ≠ 170

# %% [markdown]
# ### Question 3: Explain the significance level in hypothesis testing and its role in deciding the outcome of a test.

# %% [markdown]
# The significance level (α) is the probability of rejecting the null hypothesis when it is true (Type I error). Common values are 0.05 or 0.01. If the p-value ≤ α, we reject H₀; otherwise, we fail to reject it.

# %% [markdown]
# ### Question 4: What are Type I and Type II errors? Give examples of each.

# %% [markdown]
# - **Type I Error:** Rejecting H₀ when it is true. Example: Concluding a medicine is effective when it is not.
# - **Type II Error:** Failing to reject H₀ when it is false. Example: Concluding a medicine is not effective when it actually works.

# %% [markdown]
# ### Question 5: What is the difference between a Z-test and a T-test? Explain when to use each.

# %% [markdown]
# | Basis | Z-test | T-test |
# |--------|--------|--------|
# | Population Variance | Known | Unknown |
# | Sample Size | n > 30 | n ≤ 30 |
# | Distribution | Normal | t-distribution |
#
# Use Z-test when σ is known, and T-test when it is not.

# %% [markdown]
# ### Question 6: Write a Python program to generate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10
p = 0.5
data = np.random.binomial(n, p, 1000)

plt.hist(data, bins=range(0, 12), edgecolor='black', color='skyblue')
plt.title('Binomial Distribution (n=10, p=0.5)')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Question 7: Implement hypothesis testing using Z-statistics for a sample dataset in Python.

# %%
import numpy as np
from scipy import stats

sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
               50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
               50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
               50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

population_mean = 50
sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data, ddof=1)
n = len(sample_data)

z_stat = (sample_mean - population_mean) / (sample_std / np.sqrt(n))
p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))

print("Z-Statistic:", z_stat)
print("P-Value:", p_value)
# Out:
# Z-Statistic: 0.9940271559503017
# P-Value: 0.3202096468890012

# %% [markdown]
# ### Question 8: Write a Python script to simulate data from a normal distribution and calculate the 95% confidence interval for its mean.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

data = np.random.normal(100, 15, 1000)
mean = np.mean(data)
std = np.std(data, ddof=1)
n = len(data)

confidence = 0.95
z_value = stats.norm.ppf(1 - (1 - confidence)/2)
margin = z_value * (std / np.sqrt(n))

lower = mean - margin
upper = mean + margin

print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")

plt.hist(data, bins=30, color='lightgreen', edgecolor='black')
plt.title("Normal Distribution Data with 95% Confidence Interval")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# 95% Confidence Interval: (98.78, 100.60)

# %% [markdown]
# ### Question 9: Write a Python function to calculate the Z-scores from a dataset and visualize the standardized data using a histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_zscores(data):
    mean = np.mean(data)
    std = np.std(data)
    z_scores = (data - mean) / std
    return z_scores

data = np.random.normal(50, 10, 1000)
z_scores = calculate_zscores(data)

plt.hist(z_scores, bins=30, color='orange', edgecolor='black')
plt.title("Histogram of Z-Scores")
plt.xlabel("Z-Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Explanation:** Z-scores indicate how many standard deviations a value is from the mean. Z = 0 means the value equals the mean; Z = +1 means one standard deviation above, Z = -1 means one below.
